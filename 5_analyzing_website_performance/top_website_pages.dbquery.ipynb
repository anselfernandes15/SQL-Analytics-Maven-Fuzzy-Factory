-- %%
select 
  wp.pageview_url as pageview_url,
  count(distinct ws.website_session_id) as sessions
from workspace.mavenfuzzyfactory.website_pageviews as wp
left join workspace.mavenfuzzyfactory.website_sessions as ws
on wp.website_session_id = ws.website_session_id
group by 1
order by 2 desc
